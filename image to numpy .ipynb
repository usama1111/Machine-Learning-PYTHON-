# %%
import PIL
print('Pillow Version:', PIL.__version__)
# Out:
# Pillow Version: 6.2.0

# %%
from PIL import Image

# %%
image = Image.open('Desktop/pic.jpg')

# %%
print(image.format)
# Out:
# JPEG

# %%
print(image.size)
# Out:
# (635, 635)

# %%
print(image.mode)
# Out:
# RGB

# %%
from matplotlib import image
from matplotlib import pyplot

# %%
image=image.imread('Desktop/pic.jpg')

# %%
print(image.dtype)
# Out:
# uint8

# %%
pyplot.imshow(image)

# %%
pyplot.show()

# %%
from numpy import asarray

# %%
image = Image.open('Desktop/pic.jpg')

# %%
data = asarray(image)

# %%
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
print(data)
# Out:
# [[[34 34 34]
#   [34 34 34]
#   [34 34 34]
#   ...
#   [34 34 34]
#   [34 34 34]
#   [34 34 34]]
#
#  [[34 34 34]
#   [34 34 34]
#   [34 34 34]
#   ...
#   [34 34 34]
#   [34 34 34]
#   [34 34 34]]
#
#  [[34 34 34]
#   [34 34 34]
#   [34 34 34]
#   ...
#   [34 34 34]
#   [34 34 34]
#   [34 34 34]]
#
#  ...
#
#  [[28 39 25]
#   [28 39 25]
#   [28 39 25]
#   ...
#   [32 40 27]
#   [32 40 27]
#   [32 40 27]]
#
#  [[26 39 22]
#   [26 39 22]
#   [26 39 22]
#   ...
#   [28 39 23]
#   [28 39 23]
#   [28 39 23]]
#
#  [[67 84 65]
#   [67 84 65]
#   [67 84 65]
#   ...
#   [68 83 64]
#   [68 83 64]
#   [68 83 64]]]

# %%
import os

# %%
os.mkdir(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-ad7dda720bfb> in <module>
# ----> 1 os.mkdir(image)
#
# TypeError: mkdir: path should be string, bytes or os.PathLike, not JpegImageFile

# %%
# Out:
#   File "<ipython-input-32-f91b38c7f4e2>", line 1
#     os.listdir'
#                ^
# SyntaxError: EOL while scanning string literal
